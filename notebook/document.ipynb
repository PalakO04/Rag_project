# %% [markdown]
# ### Data Ingestion

# %%
###Docu,emt structure
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is the main content I am using to create RAG.",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Palak Makhija",
        "date_created":"16-10-2025"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Palak Makhija', 'date_created': '16-10-2025'}, page_content='This is the main content I am using to create RAG.')

# %%
## Create a simple text file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":""" Python programming Introduction.
    Python is an interpreted, object-oriented, high-level programming language with dynamic semantics.
    Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, 
    as well as for use as a scripting or glue language to connect existing components together.
    Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance.
    Python supports modules and packages, which encourages program modularity and code reuse. 
    The Python interpreter and the extensive standard library are available in source or binary form without charge 
    for all major platforms, and can be freely distributed.

    Often, programmers fall in love with Python because of the increased productivity it provides.
    Since there is no compilation step, the edit-test-debug cycle is incredibly fast. 
    Python programs is easy: a bug or bad input will never cause a segmentation fault.
    Instead, when the interpreter discovers an error, it raises an exception.
    When the program doesn't catch the exception, the interpreter prints a stack trace.
    A source level debugger allows inspection of local and global variables, evaluation of arbitrary expressions,
    setting breakpoints, stepping through the code a line at a time, and so on.
    The debugger is written in Python itself, testifying to Python's introspective power.
    On the other hand, often the quickest way to debug a program is to add a few print 
    statements to the source: the fast edit-test-debug cycle makes this simple approach very effective.""",

        "../data/text_files/machine_learnig.txt":""" Machine Learning Basics
    Machine Learning is mainly divided into three core types: Supervised, Unsupervised and Reinforcement 
    Learning along with two additional types, Semi-Supervised and Self-Supervised Learning.

    Supervised Learning: Trains models on labeled data to predict or classify new, unseen data.
    Unsupervised Learning: Finds patterns or groups in unlabeled data, like clustering or dimensionality reduction.
    Reinforcement Learning: Learns through trial and error to maximize rewards, ideal for decision-making tasks."""
}
for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding='utf-8') as f:
        f.write(content)
print("✅ Sample text files created.")
# Out:
# ✅ Sample text files created.

# %%
## TextLoader
from langchain.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content=" Python programming Introduction.\n    Python is an interpreted, object-oriented, high-level programming language with dynamic semantics.\n    Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, \n    as well as for use as a scripting or glue language to connect existing components together.\n    Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance.\n    Python supports modules and packages, which encourages program modularity and code reuse. \n    The Python interpreter and the extensive standard library are available in source or binary form without charge \n    for all major platforms, and can be freely distributed.\n\n    Often, programmers fall in love with Python because of the increased productivity it provides.\n    Since there is no compilation step, the edit-test-debug cycle is incredibly fast. \n    Python programs is easy: a bug or bad input will never cause a segmentation fault.\n    Instead, when the interpreter discovers an error, it raises an exception.\n    When the program doesn't catch the exception, the interpreter prints a stack trace.\n    A source level debugger allows inspection of local and global variables, evaluation of arbitrary expressions,\n    setting breakpoints, stepping through the code a line at a time, and so on.\n    The debugger is written in Python itself, testifying to Python's introspective power.\n    On the other hand, often the quickest way to debug a program is to add a few print \n    statements to the source: the fast edit-test-debug cycle makes this simple approach very effective.")]

# %%
##Directory Loader
from langchain_community.document_loaders import DirectoryLoader
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ##pattern to match files
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)
documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learnig.txt'}, page_content=' Machine Learning Basics\n    Machine Learning is mainly divided into three core types: Supervised, Unsupervised and Reinforcement \n    Learning along with two additional types, Semi-Supervised and Self-Supervised Learning.\n\n    Supervised Learning: Trains models on labeled data to predict or classify new, unseen data.\n    Unsupervised Learning: Finds patterns or groups in unlabeled data, like clustering or dimensionality reduction.\n    Reinforcement Learning: Learns through trial and error to maximize rewards, ideal for decision-making tasks.'),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content=" Python programming Introduction.\n    Python is an interpreted, object-oriented, high-level programming language with dynamic semantics.\n    Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, \n    as well as for use as a scripting or glue language to connect existing components together.\n    Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance.\n    Python supports modules and packages, which encourages program modularity and code reuse. \n    The Python interpreter and the extensive standard library are available in source or binary form without charge \n    for all major platforms, and can be freely distributed.\n\n    Often, programmers fall in love with Python because of the increased productivity it provides.\n    Since there is no compilation step, the edit-test-debug cycle is incredibly fast. \n    Python programs is easy: a bug or bad input will never cause a segmentation fault.\n    Instead, when the interpreter discovers an error, it raises an exception.\n    When the program doesn't catch the exception, the interpreter prints a stack trace.\n    A source level debugger allows inspection of local and global variables, evaluation of arbitrary expressions,\n    setting breakpoints, stepping through the code a line at a time, and so on.\n    The debugger is written in Python itself, testifying to Python's introspective power.\n    On the other hand, often the quickest way to debug a program is to add a few print \n    statements to the source: the fast edit-test-debug cycle makes this simple approach very effective.")]

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
##load all text files from directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ##Pattern to match files
    loader_cls= PyMuPDFLoader, ##Loader class to use
    show_progress=False
)
pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 6}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 7}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 8}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 9}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 10}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 11}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 12}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 13}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 14}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 15}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 16}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 17}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 18}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 19}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 20}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 21}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 22}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 23}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 24}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 25}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 26}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 27}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 28}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 29}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 30}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 31}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 32}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 33}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 34}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 35}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 36}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 37}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 38}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 39}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 40}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 41}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 42}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 43}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 44}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 45}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 46}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 47}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 48}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 49}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 50}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 51}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 52}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 53}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 54}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 55}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 56}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 57}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 58}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 59}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 60}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 61}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 62}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 63}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 64}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 65}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 66}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 67}, page_content=''),
#  Document(metadata={'producer': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creator': 'Adobe Scan for Android 25.05.22-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'file_path': '..\\data\\pdf\\compiler_design(notes) (1).pdf', 'total_pages': 69, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 68}, page_content=''),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 0}, page_content='SQL\nAPNA\n COLLEGE\nby'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 1}, page_content='Database\nA software application used to manage our DB is called DBMS (Database Management System)\nDatabase is collection of data in a format that can be easily accessed (Digital)\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 2}, page_content='Types of Databases\nNon-relational (NoSQL)\nRelational\nData stored in tables\ndata not stored in tables\n** We use SQL to work with relational DBMS\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 3}, page_content='What is SQL?\nSQL is a programming language used to interact with relational databases.\nStructured Query Language\nIt is used to perform CRUD operations :\nCreate\nRead\nUpdate\nDelete\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 4}, page_content='Database Structure \nDatabase\nTable 1\nData\nTable 2\nData\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 5}, page_content='What is a table?\nStudent table\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 6}, page_content='Creating our First Database\nCREATE DATABASE db_name;\nDROP DATABASE db_name;\nOur first SQL Query\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 7}, page_content='Creating our First Table\nCREATE TABLE table_name ( \n    column_name1 datatype constraint,\n    column_name2 datatype constraint,\n    column_name2 datatype constraint\n);\nUSE db_name;\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 8}, page_content='SQL Datatypes\nThey define the type of values that can be stored in a column\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 9}, page_content='SQL Datatypes\nSigned & Unsigned\nTINYINT (-128 to 127)\nTINYINT UNSIGNED (0 to 255)\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 10}, page_content='Types of SQL Commands\nDDL (Data Definition Language) : create, alter, rename, truncate & drop\nDML (Data Manipulation Language) : select, insert, update & delete\nDCL (Data Control Language) : grant & revoke permission to users\nDQL (Data Query Language) : select\nTCL (Transaction Control Language) : start transaction, commit, rollback etc. APNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 11}, page_content='Database related Queries\nCREATE DATABASE db_name;\nDROP DATABASE db_name;\nSHOW DATABASES;\nSHOW TABLES;\nCREATE DATABASE IF NOT EXISTS db_name;\nDROP DATABASE IF EXISTS db_name;\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 12}, page_content='Table related Queries\nCREATE TABLE table_name ( \n    column_name1 datatype constraint,\n    column_name2 datatype constraint,\n);\nCreate\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 13}, page_content='Table related Queries\nSELECT * FROM table_name;\nSelect & View ALL columns\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 14}, page_content='Table related Queries\nInsert\nINSERT INTO table_name \n(colname1, colname2);\nVALUES \n(col1_v1, col2_v1), \n(col1_v2, col2_v2);\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 15}, page_content='Keys\nPrimary Key\nForeign Key\nIt is a column (or set of columns) in a table that uniquely identifies each row. (a unique id)\nThere is only 1 PK & it should be NOT null.\nA foreign key is a column (or set of columns) in a table that refers to the primary key in another table.\nFKs can have duplicate & null values.\nThere can be multiple FKs.\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 16}, page_content='Keys\ntable1 - Student\ntable2 - City\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 17}, page_content='Constraints\nNOT NULL \nSQL constraints are used to specify rules for data in a table.\nUNIQUE\nPRIMARY KEY\ncolumns cannot have a null value\nall values in column are different\nmakes a column unique & not null but used only for one\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 18}, page_content='Constraints\nFOREIGN KEY\nprevent actions that would destroy links between tables\nDEFAULT\nsets the default value of a column\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 19}, page_content='Constraints\nCHECK\nit can limit the values allowed in a column\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 20}, page_content='Create this sample table\nInsert this data\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 21}, page_content='Select in Detail\nused to select any data from the database\nBasic Syntax\nSELECT  col1, col2 FROM table_name;\nTo Select ALL\nSELECT  * FROM table_name;\nAPNA\n COLLEGE'),
# ...
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 39}, page_content="Table related Queries\nTruncate (to delete table's data)\nTRUNCATE TABLE table_name ;\nAPNA\n COLLEGE"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 40}, page_content='Joins in SQL\nJoin is used to combine rows from two or more tables, based on a related column between them.\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 41}, page_content='Types of Joins\nInner Join\nLeft Join\nRight Join\nFull Join\nOuter Joins\nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 42}, page_content='Inner Join\nReturns records that have matching values in both tables\nSyntax\nSELECT column(s) \nFROM tableA \nINNER JOIN tableB \nO\ufeffN tableA.col_name = tableB.col_name; \nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 43}, page_content='Example\nSELECT * \nFROM student \nINNER JOIN course \nO\ufeffN student.student_id = course.student_id; \nstudent\ncourse\nResult\nInner Join\nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 44}, page_content='Left Join\nReturns all records from the left table, and the matched records from\nthe right table\nSyntax\nSELECT column(s) \nFROM tableA \nLEFT JOIN tableB \nO\ufeffN tableA.col_name = tableB.col_name; \nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 45}, page_content='Left Join\nExample\nSELECT * \nFROM student as s \nLEFT JOIN course as c\nO\ufeffN s.student_id = c.student_id; \nstudent\ncourse\nResult\nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 46}, page_content='Right Join\nReturns all records from the right table, and the matched records\nfrom the left table\nSyntax\nSELECT column(s) \nFROM tableA \nRIGHT JOIN tableB \nO\ufeffN tableA.col_name = tableB.col_name; \nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 47}, page_content='Right Join\nExample\nSELECT * \nFROM student as s \nRIGHT JOIN course as c\nO\ufeffN s.student_id = c.student_id; \nstudent\ncourse\nResult\nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 48}, page_content='Full Join\nReturns all records when there is a match in either left or right table\nSyntax in MySQL\nLEFT JOIN\nUNION\nRIGHT JOIN\nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 49}, page_content='Full Join\nExample\nstudent\ncourse\nResult\nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 50}, page_content='Write SQL commands to display the right exclusive join : \nQs:\nThink & Ans\nRight Exclusive Join\nLeft Exclusive Join\nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 51}, page_content='Self Join\nIt is a regular join but the table is joined with itself.\nSyntax \nSELECT column(s) \nFROM table as a \nJOIN table as b \nO\ufeffN a.col_name = b.col_name; \nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 52}, page_content='Self Join\nExample\nResult\nEmployee\nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 53}, page_content='Union\nIt is used to combine the result-set of two or more SELECT statements.\nGives UNIQUE records.\nSyntax \nSELECT column(s) FROM tableA  \nUNION \nSELECT column(s) FROM tableB  \nevery SELECT should have same no. of columns\ncolumns must have similar data types\ncolumns in every SELECT should be in same order\nTo use it : \nAPNA\nCOLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 54}, page_content='SQL Sub Queries\nA Subquery or Inner query or a Nested query is a query within another SQL query.\nQuery\nSub Query\nIt involves 2 select statements.\nSyntax \nSELECT column(s)\nFROM table_name \nWHERE col_name operator\n( subquery );\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 55}, page_content='SQL Sub Queries\nExample\nGet names of all students who scored more than class average.\nStep 1. Find the avg of class\nStep 2. Find the names of students with marks > avg\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 56}, page_content='SQL Sub Queries\nExample\nFind the names of all students with even roll numbers.\nStep 1. Find the even roll numbers\nStep 2. Find the names of students with even roll no\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 57}, page_content='SQL Sub Queries\nExample with FROM\nFind the max marks from the students of Delhi\nStep 1. Find the students of Mumbai\nStep 2. Find their max marks using the sublist in step 1\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2023-08-18T16:21:57+00:00', 'source': '..\\data\\pdf\\SQL (notes) (1).pdf', 'file_path': '..\\data\\pdf\\SQL (notes) (1).pdf', 'total_pages': 59, 'format': 'PDF 1.4', 'title': 'SQL (notes)', 'author': 'Rahul Neha', 'subject': '', 'keywords': 'DAFrbWAV1Yk,BAEHDsZUYOI', 'moddate': '2023-08-18T16:21:54+00:00', 'trapped': '', 'modDate': "D:20230818162154+00'00'", 'creationDate': "D:20230818162157+00'00'", 'page': 58}, page_content='MySQL Views\nA view is a virtual table based on the result-set of an SQL statement.\n*A view always shows up-to-date data. The\ndatabase engine recreates the view, every time a\nuser queries it.\nAPNA\n COLLEGE'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': 'ReportLab PDF Library - www.reportlab.com', 'creationdate': '2025-09-22T06:12:05+00:00', 'source': '..\\data\\pdf\\stats_cheat_sheet.pdf', 'file_path': '..\\data\\pdf\\stats_cheat_sheet.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': 'untitled', 'author': 'anonymous', 'subject': 'unspecified', 'keywords': '', 'moddate': '2025-09-22T06:12:05+00:00', 'trapped': '', 'modDate': "D:20250922061205+00'00'", 'creationDate': "D:20250922061205+00'00'", 'page': 0}, page_content='Statistics Cheat Sheet for Interviews\n1. Basics\n• Population = entire dataset | Sample = subset of population\n• Parameter = population measure | Statistic = sample measure\n2. Types of Data\n• Qualitative → Nominal (colors), Ordinal (ranks)\n• Quantitative → Discrete (counts), Continuous (height, weight)\n3. Descriptive Statistics\n• Mean, Median, Mode\n• Variance, Standard Deviation (σ), Range, IQR\n4. Probability Basics\n• P(A ∪ B) = P(A)+P(B)–P(A∩B) | P(A ∩ B)=P(A)P(B|A)\n• Bayes: P(A|B) = P(B|A)P(A)/P(B)\n5. Distributions\n• Normal (bell curve), Bernoulli (0/1), Binomial (#successes),\n• Poisson (rare events), Uniform (equal chance), Exponential (time to event)\n6. Hypothesis Testing\n• Null (H0): no effect | Alternative (H1): effect exists\n• p-value < 0.05 → reject H0\n• Type I Error (false positive) | Type II Error (false negative)\n7. Confidence Intervals\n• CI = estimate ± margin of error\n• 95% CI → 95% intervals contain true parameter\n8. Correlation & Regression\n• Correlation (r: -1 to 1), Covariance\n• Linear Regression: y = β0 + β1x + ε | R² = variance explained')]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
